# %%
import pandas as pd
from pandas.tools.plotting import autocorrelation_plot

# %%
shear_df = pd.read_csv('shear1.csv')

# %%
shear_df.head(10)
# Out:
#    H49  H39  H30  H10  Mean49  SD49  Max49  Min49  Mean39  SD39    ...     \
# 0   49   39   30   10    2.80  0.38   3.80   1.88    2.58  0.45    ...
# 1   49   39   30   10    2.29  0.59   3.80   1.12    1.79  0.91    ...
# 2   49   39   30   10    2.64  0.64   4.17   1.12    2.24  0.83    ...
# 3   49   39   30   10    2.71  0.54   3.80   1.12    2.52  0.67    ...
# 4   49   39   30   10    3.14  0.54   4.17   1.50    2.95  0.62    ...
# 5   49   39   30   10    1.98  1.23   4.94   0.35    1.69  1.29    ...
# 6   49   39   30   10    3.17  0.56   4.56   1.88    2.88  0.56    ...
# 7   49   39   30   10    2.33  0.83   4.17   0.35    1.95  0.99    ...
# 8   49   39   30   10    2.37  0.64   3.80   0.35    2.03  0.87    ...
# 9   49   39   30   10    2.80  1.13   5.32   0.73    2.51  1.29    ...
#
#    MeanWD  SDWD  MaxWD  MinWD  MeanTemp  SDTemp  MaxTemp  MinTemp       Date  \
# 0     277    10    273      0      75.9     0.0     76.1     75.6  6/30/2003
# 1     284    14    307      0      76.1     0.0     76.1     75.6  6/30/2003
# 2     287    15    272      0      76.4     0.0     76.7     76.1  6/30/2003
# 3     277    11    297      0      76.3     0.0     76.7     76.1  6/30/2003
# 4     246     8    253      0      76.4     0.0     76.7     76.1  6/30/2003
# 5     226    17    234      0      77.1     0.3     77.8     76.1  6/30/2003
# 6     259    15    246      0      76.7     0.0     77.2     76.1  6/30/2003
# 7     271    28    252      0      77.4     0.3     78.3     76.7  6/30/2003
# 8     256    20    282      0      77.4     0.0     77.8     77.2  6/30/2003
# 9     249    15    238      0      77.1     0.3     77.8     76.1  6/30/2003
#
#        Time
# 0   9:50:00
# 1  10:00:00
# 2  10:10:00
# 3  10:20:00
# 4  10:30:00
# 5  10:40:00
# 6  10:50:00
# 7  11:00:00
# 8  11:10:00
# 9  11:20:00
#
# [10 rows x 30 columns]

# %%
series = shear_df[['Date', 'SD49']]
# Out:
#           Date  SD49
# 0    6/30/2003  0.38
# 1    6/30/2003  0.59
# 2    6/30/2003  0.64
# 3    6/30/2003  0.54
# 4    6/30/2003  0.54
# 5    6/30/2003  1.23
# 6    6/30/2003  0.56
# 7    6/30/2003  0.83
# 8    6/30/2003  0.64
# 9    6/30/2003  1.13
# 10   6/30/2003  0.73
# 11   6/30/2003  0.67
# 12   6/30/2003  0.83
# 13   6/30/2003  0.77
# 14   6/30/2003  0.67
# 15   6/30/2003  0.67
# 16   6/30/2003  0.70
# 17   6/30/2003  0.59
# 18   6/30/2003  0.83
# 19   6/30/2003  1.23
# 20   6/30/2003  1.18
# 21   6/30/2003  0.80
# 22   6/30/2003  1.04
# 23   6/30/2003  0.91
# 24   6/30/2003  0.47
# 25   6/30/2003  0.54
# 26   6/30/2003  0.62
# 27   6/30/2003  1.04
# 28   6/30/2003  0.73
# 29   6/30/2003  0.80
# ..         ...   ...
# 690   7/5/2003  0.35
# 691   7/5/2003  0.59
# 692   7/5/2003  0.67
# 693   7/5/2003  0.52
# 694   7/5/2003  0.24
# 695   7/5/2003  0.22
# 696   7/5/2003  0.83
# 697   7/5/2003  0.80
# 698   7/5/2003  0.02
# 699   7/5/2003  0.59
# 700   7/5/2003  0.64
# 701   7/5/2003  0.47
# 702   7/5/2003  0.62
# 703   7/5/2003  0.73
# 704   7/5/2003  0.73
# 705   7/5/2003  0.37
# 706   7/5/2003  0.37
# 707   7/5/2003  0.50
# 708   7/5/2003  0.64
# 709   7/5/2003  0.45
# 710   7/5/2003  0.56
# 711   7/5/2003  0.47
# 712   7/5/2003  0.47
# 713   7/5/2003  0.47
# 714   7/5/2003  0.52
# 715   7/5/2003  0.44
# 716   7/5/2003  0.56
# 717   7/5/2003  0.83
# 718   7/5/2003  0.54
# 719   7/5/2003  0.70
#
# [720 rows x 2 columns]

# %%
shear_df.loc[0:2, :].head(10)
# Out:
#    H49  H39  H30  H10  Mean49  SD49  Max49  Min49  Mean39  SD39    ...     \
# 0   49   39   30   10    2.80  0.38   3.80   1.88    2.58  0.45    ...
# 1   49   39   30   10    2.29  0.59   3.80   1.12    1.79  0.91    ...
# 2   49   39   30   10    2.64  0.64   4.17   1.12    2.24  0.83    ...
#
#    MeanWD  SDWD  MaxWD  MinWD  MeanTemp  SDTemp  MaxTemp  MinTemp       Date  \
# 0     277    10    273      0      75.9     0.0     76.1     75.6  6/30/2003
# 1     284    14    307      0      76.1     0.0     76.1     75.6  6/30/2003
# 2     287    15    272      0      76.4     0.0     76.7     76.1  6/30/2003
#
#        Time
# 0   9:50:00
# 1  10:00:00
# 2  10:10:00
#
# [3 rows x 30 columns]

# %%
shear_df.iloc[:, (0, 3)].head(6)
# Out:
#    H49  H10
# 0   49   10
# 1   49   10
# 2   49   10
# 3   49   10
# 4   49   10
# 5   49   10

# %%
shear_df.ix[0:, ('Mean49')]
# Out:
# 0      2.80
# 1      2.29
# 2      2.64
# 3      2.71
# 4      3.14
# 5      1.98
# 6      3.17
# 7      2.33
# 8      2.37
# 9      2.80
# 10     2.61
# 11     3.81
# 12     3.95
# 13     3.27
# 14     1.06
# 15     4.03
# 16     3.06
# 17     3.08
# 18     1.63
# 19     3.57
# 20     3.18
# 21     3.95
# 22     1.56
# 23     3.59
# 24     2.39
# 25     3.60
# 26     2.82
# 27     2.21
# 28     2.77
# 29     1.48
#        ...
# 690    5.66
# 691    4.64
# 692    3.82
# 693    3.88
# 694    3.11
# 695    3.28
# 696    1.61
# 697    1.76
# 698    0.35
# 699    2.16
# 700    1.95
# 701    3.38
# 702    3.35
# 703    4.97
# 704    4.75
# 705    3.38
# 706    3.01
# 707    2.67
# 708    1.49
# 709    1.27
# 710    1.57
# 711    2.05
# 712    1.63
# 713    2.29
# 714    2.09
# 715    2.56
# 716    1.46
# 717    1.70
# 718    0.86
# 719    1.02
# Name: Mean49, dtype: float64

# %%
from pandas.tools.plotting import autocorrelation_plot

# %%
autocorrelation_plot(shear_df[['Date', 'SD49']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-4eced3d85c7e> in <module>()
# ----> 1 autocorrelation_plot(shear_df[['Date', 'SD49']])
#
# /home/ethels/anaconda3/lib/python3.6/site-packages/pandas/tools/plotting.py in autocorrelation_plot(series, ax, **kwds)
#     840     if ax is None:
#     841         ax = plt.gca(xlim=(1, n), ylim=(-1.0, 1.0))
# --> 842     mean = np.mean(data)
#     843     c0 = np.sum((data - mean) ** 2) / float(n)
#     844
#
# /home/ethels/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    2940
#    2941     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2942                             out=out, **kwargs)
#    2943
#    2944
#
# /home/ethels/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      63         dtype = mu.dtype('f8')
#      64
# ---> 65     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      66     if isinstance(ret, mu.ndarray):
#      67         ret = um.true_divide(
#
# TypeError: must be str, not float

# %%
shear_df.dtypes
# Out:
# H49           int64
# H39           int64
# H30           int64
# H10           int64
# Mean49      float64
# SD49        float64
# Max49       float64
# Min49       float64
# Mean39      float64
# SD39        float64
# Max39       float64
# Min39       float64
# Mean30      float64
# SD30        float64
# Max30       float64
# Min30       float64
# Mean10      float64
# SD10        float64
# Max10       float64
# Min10       float64
# MeanWD        int64
# SDWD          int64
# MaxWD         int64
# MinWD         int64
# MeanTemp    float64
# SDTemp      float64
# MaxTemp     float64
# MinTemp     float64
# Date         object
# Time         object
# dtype: object

# %%
shear_df.MeanWD.describe()
# Out:
# count    720.000000
# mean     211.069444
# std       66.900031
# min        5.000000
# 25%      189.000000
# 50%      217.500000
# 75%      254.000000
# max      356.000000
# Name: MeanWD, dtype: float64
